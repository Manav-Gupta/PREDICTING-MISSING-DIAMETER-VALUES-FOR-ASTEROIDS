# %% [markdown]
# <a href="https://colab.research.google.com/github/Manav-Gupta/asteroid-LSTM/blob/main/asteroid_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importing all the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
import keras
from pandas import DataFrame
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import Adam
from datetime import datetime
from sklearn.decomposition import PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset=pd.read_csv('drive/My Drive/results.csv')
dataset.head(5)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10,26,33,40,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                   full_name         a  ...  diameter_sigma          per
# 0         1 Ceres (A801 AA)  2.769165  ...           0.200  1683.145703
# 1        2 Pallas (A802 FA)  2.773841  ...          18.000  1687.410992
# 2          3 Juno (A804 RA)  2.668285  ...          10.594  1592.013769
# 3         4 Vesta (A807 FA)  2.361418  ...           0.200  1325.432763
# 4       5 Astraea (A845 XA)  2.574037  ...           3.140  1508.414420
#
# [5 rows x 49 columns]

# %%
dataset.drop(columns=['condition_code','n_obs_used','n_del_obs_used','n_dop_obs_used','condition_code.1','a.1','e.1','i.1','om.1','w.1','q.1','ad.1','per_y.1','data_arc.1','condition_code.1','n_obs_used.1','n_del_obs_used.1','n_dop_obs_used.1','H.1','extent','pha','neo','IR','full_name','full_name.1'],inplace=True)

# %%
dataset.columns
# Out:
# Index(['a', 'e', 'i', 'om', 'w', 'q', 'ad', 'per_y', 'data_arc', 'H',
#        'diameter', 'albedo', 'rot_per', 'GM', 'BV', 'UB', 'spec_B', 'spec_T',
#        'G', 'moid', 'class', 'n', 'ma', 'diameter_sigma', 'per'],
#       dtype='object')

# %%
#dataset.dropna(subset=['diameter','albedo','H'])

# %%
dataset['diameter']=pd.to_numeric(dataset['diameter'],errors='coerce')
dataset['spec_B']=pd.to_numeric(dataset['spec_B'],errors='coerce')
dataset['spec_T']=pd.to_numeric(dataset['spec_T'],errors='coerce')
dataset['class']=pd.to_numeric(dataset['class'],errors='coerce')

# %%
dataset = dataset[dataset['diameter'].notnull()]

# %%
dataset.to_csv('check.csv')

# %%
for column in dataset.columns:
    print(column, dataset[column].isna().sum()/dataset.shape[0])
# Out:
# a 0.0
# e 0.0
# i 0.0
# om 0.0
# w 0.0
# q 0.0
# ad 0.0
# per_y 0.0
# data_arc 0.0003856784727132481
# H 0.020055280581088897
# diameter 0.0
# albedo 0.008249233999700028
# rot_per 0.9028018826823223
# GM 0.9999000092848521
# BV 0.9928078107032918
# UB 0.9931006406547963
# spec_B 1.0
# spec_T 1.0
# G 0.9991500789212431
# moid 0.0
# class 1.0
# n 0.0
# ma 0.0
# diameter_sigma 0.0008999164363309121
# per 0.0

# %%
tooMuchNa = dataset.columns[dataset.isna().sum()/dataset.shape[0] > 0.5]
dataset = dataset.drop(tooMuchNa,axis=1)

# %%
dataset.columns
dataset=dataset.fillna(dataset['H'].mode())

# %%
dataset=dataset.fillna(dataset.mean())

# %%
#dataset=dataset.sample(frac= 1)

# %%
dataset.columns
# Out:
# Index(['a', 'e', 'i', 'om', 'w', 'q', 'ad', 'per_y', 'data_arc', 'H',
#        'diameter', 'albedo', 'moid', 'n', 'ma', 'diameter_sigma', 'per'],
#       dtype='object')

# %%
datasetc=dataset.corr()
datasetc
# Out:
#                        a         e  ...  diameter_sigma       per
# a               1.000000  0.010390  ...        0.201096  0.938924
# e               0.010390  1.000000  ...       -0.016787  0.044451
# i               0.151783  0.166829  ...        0.040714  0.096666
# om             -0.000351  0.002089  ...       -0.001849  0.000462
# w              -0.002328  0.011458  ...        0.001718 -0.001636
# q               0.373626 -0.540449  ...        0.360839  0.111740
# ad              0.984952  0.111654  ...        0.144837  0.969338
# per_y           0.938924  0.044451  ...        0.081167  1.000000
# data_arc       -0.026846 -0.050940  ...        0.011496 -0.009247
# H              -0.130929  0.253444  ...       -0.080778 -0.036027
# diameter        0.147350 -0.060931  ...        0.344263  0.050428
# albedo         -0.116290 -0.021583  ...       -0.084648 -0.020811
# moid            0.377739 -0.510767  ...        0.365538  0.113728
# n              -0.279414  0.215717  ...       -0.138668 -0.059722
# ma              0.008972 -0.010984  ...       -0.023157 -0.005902
# diameter_sigma  0.201096 -0.016787  ...        1.000000  0.081167
# per             0.938924  0.044451  ...        0.081167  1.000000
#
# [17 rows x 17 columns]

# %%
#,'rot_per','GM','BV','UB','spec_B','spec_T','G'
#dataset1 = dataset[['a','e','i','om','w','q','ad','per_y','data_arc','H','albedo','moid','n','ma','diameter_sigma','per']]

# %%
dataset1 = dataset[['a','i','q','ad','data_arc','moid','diameter_sigma']]
print(dataset.head(20))
# Out:
#            a         e          i  ...          ma  diameter_sigma          per
# 0   2.769165  0.076009  10.594067  ...   77.372098        0.200000  1683.145703
# 1   2.773841  0.229972  34.832931  ...  144.975676       18.000000  1687.410992
# 2   2.668285  0.256936  12.991043  ...  125.435355       10.594000  1592.013769
# 3   2.361418  0.088721   7.141771  ...   95.861938        0.200000  1325.432763
# 4   2.574037  0.190913   5.367427  ...   17.846344        3.140000  1508.414420
# 5   2.424533  0.203219  14.739653  ...  190.686496        2.900000  1378.924506
# 6   2.387375  0.230145   5.521598  ...  247.425812       10.000000  1347.347071
# 7   2.201415  0.155833   5.889081  ...  315.318013        1.025000  1193.029574
# 8   2.386189  0.123300   5.576494  ...   23.912205        0.485994  1346.343281
# 9   3.142435  0.112117   3.831786  ...  222.850543        6.800000  2034.688644
# 10  2.452390  0.099823   4.631823  ...   21.701825        1.008000  1402.757738
# 11  2.333778  0.220439   8.372749  ...  243.834733        1.199000  1302.229877
# 12  2.576064  0.085283  16.535532  ...  283.002605       50.084000  1510.196192
# 13  2.586377  0.166250   9.121448  ...  259.795715        0.485994  1519.274373
# 14  2.643690  0.186178  11.753619  ...   15.025609        2.234000  1570.052431
# 15  2.922776  0.133531   3.096560  ...    7.048521       23.000000  1825.120868
# 16  2.470965  0.133323   5.592661  ...   45.074275        2.027000  1418.725045
# 17  2.295709  0.217505  10.131591  ...   20.462100        2.452000  1270.496864
# 18  2.442857  0.156975   1.572666  ...  300.346238        0.485994  1394.586682
# 19  2.409358  0.142494   0.708567  ...  222.460322        3.674000  1365.999296
#
# [20 rows x 17 columns]

# %%
#Seperating the output and features

#dataset1=dataset.values
dataset2=dataset['diameter'].values
dataset.head()
# Out:
#           a         e          i  ...          ma  diameter_sigma          per
# 0  2.769165  0.076009  10.594067  ...   77.372098           0.200  1683.145703
# 1  2.773841  0.229972  34.832931  ...  144.975676          18.000  1687.410992
# 2  2.668285  0.256936  12.991043  ...  125.435355          10.594  1592.013769
# 3  2.361418  0.088721   7.141771  ...   95.861938           0.200  1325.432763
# 4  2.574037  0.190913   5.367427  ...   17.846344           3.140  1508.414420
#
# [5 rows x 17 columns]

# %%
#Scaling data
scale_x = MinMaxScaler(feature_range=(0,1))
scaled_x=scale_x.fit_transform(dataset1)
print(scaled_x.shape)
#pca= PCA(n_components=4)
#scaled_x = pca.fit_transform(scaled_x)

dataset2=dataset2.reshape(-1, 1)
scale_y = MinMaxScaler(feature_range=(0,1))
scaled_y=scale_y.fit_transform(dataset2)
print(scaled_y.shape)
#print(principalComponents)
print(scaled_x)
# Out:
# (140013, 7)
# (140013, 1)
# [[0.00570697 0.06207417 0.06155793 ... 0.11710958 0.04051714 0.00142857]
#  [0.00571942 0.20439407 0.05105128 ... 1.         0.03135834 0.12857143]
#  [0.00543831 0.07614815 0.04724305 ... 0.99934101 0.02627704 0.07567143]
#  ...
#  [0.0054638  0.09806536 0.04831215 ... 0.08976162 0.02666169 0.00346429]
#  [0.00576988 0.05069223 0.05655463 ... 0.04762448 0.03484691 0.00605714]
#  [0.00561283 0.08861884 0.04893609 ... 0.06646897 0.02860504 0.00138571]]

# %%
#Converting data into readable format of LSTM for previous 24 timesteps
x=list()
y=list()
ws=100
for i in range(len(dataset)-ws):
  xx=list()
  for j in range(0,ws-1,1):
    value=scaled_x[i+j]
    xx.append(value)
  x.append(xx)
  yy=scaled_y[i+ws-1]
  y.append(yy)
#Input of  LSTM 
x=np.array(x)
#Output of LSTM
y=np.array(y)
print(x.shape)
# Out:
# (139913, 99, 7)

# %%
#Splitting data into training 70% , testing 15% and validation 15%
n_train_hours = 97931
n_valid_hours = 118917

train_x = x[:n_train_hours]
test_x = x[n_valid_hours:]
valid_x= x[n_train_hours:n_valid_hours]

train_y = y[:n_train_hours]
test_y = y[n_valid_hours:]
valid_y= y[n_train_hours:n_valid_hours]

# %%
#Declarationof model
model = Sequential()
#adding LSTM layer
model.add(LSTM(64, input_shape=(9,7),kernel_initializer='truncated_normal'))
model.add(Dense(1,activation='linear'))
model.compile(loss='mae', optimizer=Adam(lr=0.01))
#Training the model
history = model.fit(train_x, train_y, epochs=100, batch_size=25000, validation_data=(valid_x, valid_y), verbose=1, shuffle=False)
#Plotting the loss graphs
plt.plot(history.history['loss'], label='train')
#plt.plot(history.history['val_loss'], label='valid')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 9, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 9, 7), dtype=tf.float32, name='lstm_4_input'), name='lstm_4_input', description="created by layer 'lstm_4_input'"), but it was called on an input with incompatible shape (None, 99, 7).
# WARNING:tensorflow:Model was constructed with shape (None, 9, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 9, 7), dtype=tf.float32, name='lstm_4_input'), name='lstm_4_input', description="created by layer 'lstm_4_input'"), but it was called on an input with incompatible shape (None, 99, 7).
# 4/4 [==============================] - ETA: 0s - loss: 0.0643WARNING:tensorflow:Model was constructed with shape (None, 9, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 9, 7), dtype=tf.float32, name='lstm_4_input'), name='lstm_4_input', description="created by layer 'lstm_4_input'"), but it was called on an input with incompatible shape (None, 99, 7).
# 4/4 [==============================] - 4s 712ms/step - loss: 0.0654 - val_loss: 0.0218
# Epoch 2/100
# 4/4 [==============================] - 2s 562ms/step - loss: 0.0095 - val_loss: 0.0023
# Epoch 3/100
# 4/4 [==============================] - 2s 562ms/step - loss: 0.0064 - val_loss: 0.0046
# Epoch 4/100
# 4/4 [==============================] - 2s 565ms/step - loss: 0.0073 - val_loss: 0.0118
# Epoch 5/100
# 4/4 [==============================] - 2s 560ms/step - loss: 0.0116 - val_loss: 0.0072
# Epoch 6/100
# 4/4 [==============================] - 2s 568ms/step - loss: 0.0074 - val_loss: 0.0037
# Epoch 7/100
# 4/4 [==============================] - 2s 564ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 8/100
# 4/4 [==============================] - 2s 558ms/step - loss: 0.0059 - val_loss: 0.0022
# Epoch 9/100
# 4/4 [==============================] - 2s 563ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 10/100
# 4/4 [==============================] - 2s 562ms/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 11/100
# 4/4 [==============================] - 2s 564ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 12/100
# 4/4 [==============================] - 2s 573ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 13/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 14/100
# 4/4 [==============================] - 2s 567ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 15/100
# 4/4 [==============================] - 2s 571ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 16/100
# 4/4 [==============================] - 2s 561ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 17/100
# 4/4 [==============================] - 2s 569ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 18/100
# 4/4 [==============================] - 2s 566ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 19/100
# 4/4 [==============================] - 2s 562ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 20/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 21/100
# 4/4 [==============================] - 2s 578ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 22/100
# 4/4 [==============================] - 2s 566ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 23/100
# 4/4 [==============================] - 2s 579ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 24/100
# 4/4 [==============================] - 2s 570ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 25/100
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 26/100
# 4/4 [==============================] - 2s 579ms/step - loss: 0.0047 - val_loss: 0.0024
# Epoch 27/100
# 4/4 [==============================] - 2s 615ms/step - loss: 0.0050 - val_loss: 0.0027
# Epoch 28/100
# 4/4 [==============================] - 2s 570ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 29/100
# 4/4 [==============================] - 2s 569ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 30/100
# 4/4 [==============================] - 2s 568ms/step - loss: 0.0053 - val_loss: 0.0032
# Epoch 31/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0059 - val_loss: 0.0038
# Epoch 32/100
# 4/4 [==============================] - 2s 573ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 33/100
# 4/4 [==============================] - 2s 580ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 34/100
# 4/4 [==============================] - 2s 574ms/step - loss: 0.0048 - val_loss: 0.0022
# Epoch 35/100
# 4/4 [==============================] - 2s 576ms/step - loss: 0.0049 - val_loss: 0.0023
# Epoch 36/100
# 4/4 [==============================] - 2s 569ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 37/100
# 4/4 [==============================] - 2s 570ms/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 38/100
# 4/4 [==============================] - 2s 571ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 39/100
# 4/4 [==============================] - 2s 574ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 40/100
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 41/100
# 4/4 [==============================] - 2s 577ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 42/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 43/100
# 4/4 [==============================] - 2s 567ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 44/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 45/100
# 4/4 [==============================] - 2s 576ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 46/100
# 4/4 [==============================] - 2s 571ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 47/100
# 4/4 [==============================] - 2s 576ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 48/100
# 4/4 [==============================] - 2s 570ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 49/100
# 4/4 [==============================] - 2s 571ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 50/100
# 4/4 [==============================] - 2s 578ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 51/100
# 4/4 [==============================] - 2s 567ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 52/100
# 4/4 [==============================] - 2s 574ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 53/100
# 4/4 [==============================] - 2s 569ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 54/100
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 55/100
# 4/4 [==============================] - 2s 570ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 56/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 57/100
# 4/4 [==============================] - 2s 578ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 58/100
# 4/4 [==============================] - 2s 570ms/step - loss: 0.0045 - val_loss: 0.0023
# Epoch 59/100
# 4/4 [==============================] - 2s 568ms/step - loss: 0.0046 - val_loss: 0.0023
# Epoch 60/100
# 4/4 [==============================] - 2s 567ms/step - loss: 0.0044 - val_loss: 0.0022
# Epoch 61/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 62/100
# 4/4 [==============================] - 2s 569ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 63/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0046 - val_loss: 0.0024
# Epoch 64/100
# 4/4 [==============================] - 2s 576ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 65/100
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 66/100
# 4/4 [==============================] - 2s 567ms/step - loss: 0.0047 - val_loss: 0.0030
# Epoch 67/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0053 - val_loss: 0.0026
# Epoch 68/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0043 - val_loss: 0.0020
# Epoch 69/100
# 4/4 [==============================] - 2s 577ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 70/100
# 4/4 [==============================] - 2s 571ms/step - loss: 0.0042 - val_loss: 0.0020
# Epoch 71/100
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 72/100
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 73/100
# 4/4 [==============================] - 2s 573ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 74/100
# 4/4 [==============================] - 2s 579ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 75/100
# 4/4 [==============================] - 2s 576ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 76/100
# 4/4 [==============================] - 2s 571ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 77/100
# 4/4 [==============================] - 2s 568ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 78/100
# 4/4 [==============================] - 2s 574ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 79/100
# 4/4 [==============================] - 2s 570ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 80/100
# 4/4 [==============================] - 2s 577ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 81/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 82/100
# 4/4 [==============================] - 2s 565ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 83/100
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 84/100
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 85/100
# 4/4 [==============================] - 2s 576ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 86/100
# 4/4 [==============================] - 2s 573ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 87/100
# 4/4 [==============================] - 2s 571ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 88/100
# 4/4 [==============================] - 2s 580ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 89/100
# 4/4 [==============================] - 2s 567ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 90/100
# 4/4 [==============================] - 2s 570ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 91/100
# 4/4 [==============================] - 2s 574ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 92/100
# 4/4 [==============================] - 2s 574ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 93/100
# 4/4 [==============================] - 2s 616ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 94/100
# 4/4 [==============================] - 2s 571ms/step - loss: 0.0044 - val_loss: 0.0023
# Epoch 95/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 96/100
# 4/4 [==============================] - 2s 574ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 97/100
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 98/100
# 4/4 [==============================] - 2s 576ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 99/100
# 4/4 [==============================] - 2s 569ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 100/100
# 4/4 [==============================] - 2s 573ms/step - loss: 0.0041 - val_loss: 0.0018

# %%
#Rescaling the data 
import sklearn.metrics as metrics
yhat = model.predict(test_x)

inv_yhat = scale_y.inverse_transform(yhat)

inv_y = scale_y.inverse_transform(test_y)

#Findig the accuracy with RMSE function
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
acc = metrics.r2_score(inv_y, inv_yhat)
print(acc)
print('Test RMSE: %.3f' % rmse)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 9, 9) for input KerasTensor(type_spec=TensorSpec(shape=(None, 9, 9), dtype=tf.float32, name='lstm_3_input'), name='lstm_3_input', description="created by layer 'lstm_3_input'"), but it was called on an input with incompatible shape (None, 99, 9).
# -0.28350547931788395
# Test RMSE: 1.918

# %%
nrmse=rmse/np.mean(inv_y)
nrmse
# Out:
# 0.594228772568125

# %%
#Saving the actual and predicted data 
a=np.asmatrix(inv_y)
b=np.asmatrix(inv_yhat)
np.savetxt("actualLSTM.csv", a, delimiter=",")
np.savetxt("predictLSTM.csv", b, delimiter=",")
